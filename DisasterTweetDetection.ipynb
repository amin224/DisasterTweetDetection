# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter
from os import path
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
import xgboost
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')
import sklearn.metrics as mt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Classification of Disaster Tweets with Machine Learning

# %%
train_data = pd.read_csv("./datasets/train.csv")
test_data = pd.read_csv("./datasets/test.csv")
sample_submission = pd.read_csv("./datasets/sample_submission.csv")
df_train = train_data.copy()
df_test = test_data.copy()

# %%
df_train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
df_train.describe()
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %%
print(df_train.duplicated(['text']).sum())
# Out:
# 110

# %%
df_train = df_train.drop(index=df_train[df_train.duplicated('text', keep=False)].index)

# %%
len(df_train['keyword'].unique())
# Out:
# 222

# %%
sns.countplot(x="target", data=df_train);

# %%
df_train["target"].value_counts().plot.pie(autopct='%1.1f%%', explode = [0, 0.1], figsize = (6, 6),shadow = True)
plt.title("Distribution Ratio of Disaster-Related and Non-Disaster-Related Tweets");

# %%
sns.barplot(y=df_train['keyword'].value_counts()[:20].index,x=df_train['keyword'].value_counts()[:20], orient='h');

# %%
encoder = LabelEncoder()
df_train['keyword'] = encoder.fit_transform(df_train['keyword'])
df_test['keyword'] = encoder.transform(df_test['keyword'])

# %%
df_train.head(250)
# Out:
#       id  keyword                       location  \
# 0      1      221                            NaN
# 1      4      221                            NaN
# 2      5      221                            NaN
# 3      6      221                            NaN
# 4      7      221                            NaN
# ..   ...      ...                            ...
# 253  360        6                            NaN
# 254  361        6  CA physically- Boston Strong?
# 255  363        6                  United States
# 256  364        6                            NaN
# 257  365        6                            NaN
#
#                                                   text  target
# 0    Our Deeds are the Reason of this #earthquake M...       1
# 1               Forest fire near La Ronge Sask. Canada       1
# 2    All residents asked to 'shelter in place' are ...       1
# 3    13,000 people receive #wildfires evacuation or...       1
# 4    Just got sent this photo from Ruby #Alaska as ...       1
# ..                                                 ...     ...
# 253  U.S National Park Services Tonto National Fore...       1
# 254  @TheEllenShow Please check into Salt River hor...       0
# 255  Are souls punished withåÊannihilation? http://...       0
# 256  @CalFreedomMom @steph93065 not to mention a ma...       1
# 257  @willienelson We need help! Horses will die!Pl...       1
#
# [250 rows x 5 columns]

# %%
df_train['location'].replace({'United States':'USA',
                           'New York':'USA',
                            "London":'UK',
                            "Los Angeles, CA":'USA',
                            "Washington, D.C.":'USA',
                            "California":'USA',
                             "Chicago, IL":'USA',
                             "Chicago":'USA',
                            "New York, NY":'USA',
                            "California, USA":'USA',
                            "FLorida":'USA',
                            "Nigeria":'Africa',
                            "Kenya":'Africa',
                            "Everywhere":'Worldwide',
                            "San Francisco":'USA',
                            "Florida":'USA',
                            "United Kingdom":'UK',
                            "Los Angeles":'USA',
                            "Toronto":'Canada',
                            "San Francisco, CA":'USA',
                            "NYC":'USA',
                            "Seattle":'USA',
                            "Earth":'Worldwide',
                            "Ireland":'UK',
                            "London, England":'UK',
                            "New York City":'USA',
                            "Texas":'USA',
                            "London, UK":'UK',
                            "Atlanta, GA":'USA',
                            "Mumbai":"India"},inplace=True)

# %%
sns.barplot(y=df_train['location'].value_counts()[:5].index,x=df_train['location'].value_counts()[:5], orient='h')
# Out:
# <Axes: xlabel='count', ylabel='location'>

# %%
missing_cols = ['keyword', 'location']

# create bar plots for each set
fig, axes = plt.subplots(ncols=2, figsize=(17, 4), dpi=100)
for i, df in enumerate([df_train, df_test]):
    sns.barplot(x=missing_cols, y=df[missing_cols].isnull().sum().values, ax=axes[i])
    axes[i].set_ylabel('Missing Value Count', size=15, labelpad=20)
    axes[i].tick_params(axis='x', labelsize=15)
    axes[i].tick_params(axis='y', labelsize=15)
    axes[i].set_title(['Training Set', 'Test Set'][i], fontsize=13)

# impute missing values with "no_{col}"
for df in [df_train, df_test]:
    df[missing_cols] = df[missing_cols].fillna(f'no_{{col}}')

plt.show()

# %%
df_train["keyword"].fillna("None", inplace=True)
df_test["keyword"].fillna("None", inplace=True)

df_train["location"].fillna("None", inplace=True)
df_test["location"].fillna("None", inplace=True)

# %%
df = pd.concat([df_train, df_test], ignore_index=True)

# %%
df
# Out:
#           id  keyword  location  \
# 0          1      221  no_{col}
# 1          4      221  no_{col}
# 2          5      221  no_{col}
# 3          6      221  no_{col}
# 4          7      221  no_{col}
# ...      ...      ...       ...
# 10692  10861      221  no_{col}
# 10693  10865      221  no_{col}
# 10694  10868      221  no_{col}
# 10695  10874      221  no_{col}
# 10696  10875      221  no_{col}
#
#                                                     text  target
# 0      Our Deeds are the Reason of this #earthquake M...     1.0
# 1                 Forest fire near La Ronge Sask. Canada     1.0
# 2      All residents asked to 'shelter in place' are ...     1.0
# 3      13,000 people receive #wildfires evacuation or...     1.0
# 4      Just got sent this photo from Ruby #Alaska as ...     1.0
# ...                                                  ...     ...
# 10692  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...     NaN
# 10693  Storm in RI worse than last hurricane. My city...     NaN
# 10694  Green Line derailment in Chicago http://t.co/U...     NaN
# 10695  MEG issues Hazardous Weather Outlook (HWO) htt...     NaN
# 10696  #CityofCalgary has activated its Municipal Eme...     NaN
#
# [10697 rows x 5 columns]

# %%
df = df.drop(['id'], axis=1)

# %%
x_df = df.copy()

# %%
x_df["text"].str.len()
# Out:
# 0         69
# 1         38
# 2        133
# 3         65
# 4         88
#         ...
# 10692     55
# 10693    139
# 10694     55
# 10695     65
# 10696     68
# Name: text, Length: 10697, dtype: int64

# %%
plt.figure(figsize=(12,8))
fg = sns.pairplot(data=x_df, hue="target")
plt.show(fg)

# %%
df = df.reset_index(drop=True)
df.head(50)
# Out:
#     keyword                       location  \
# 0       221                       no_{col}
# 1       221                       no_{col}
# 2       221                       no_{col}
# 3       221                       no_{col}
# 4       221                       no_{col}
# 5       221                       no_{col}
# 6       221                       no_{col}
# 7       221                       no_{col}
# 8       221                       no_{col}
# 9       221                       no_{col}
# 10      221                       no_{col}
# 11      221                       no_{col}
# 12      221                       no_{col}
# 13      221                       no_{col}
# 14      221                       no_{col}
# 15      221                       no_{col}
# 16      221                       no_{col}
# 17      221                       no_{col}
# 18      221                       no_{col}
# 19      221                       no_{col}
# 20      221                       no_{col}
# 21      221                       no_{col}
# 22      221                       no_{col}
# 23      221                       no_{col}
# 24      221                       no_{col}
# 25      221                       no_{col}
# 26      221                       no_{col}
# 27      221                       no_{col}
# 28      221                       no_{col}
# 29      221                       no_{col}
# 30      221                       no_{col}
# 31        0                     Birmingham
# 32        0  Est. September 2012 - Bristol
# 33        0                         AFRICA
# 34        0               Philadelphia, PA
# 35        0                             UK
# 36        0                       Pretoria
# 37        0                   World Wide!!
# 38        0                       no_{col}
# 39        0                 Paranaque City
# 40        0                       no_{col}
# 41        0                      milky way
# 42        0                       no_{col}
# 43        0                       no_{col}
# 44        0                       no_{col}
# 45        0      GREENSBORO,NORTH CAROLINA
# 46        0                       no_{col}
# 47        0                       England.
# 48        0       Sheffield Township, Ohio
# 49        0                          India
#
#                                                  text  target
# 0   Our Deeds are the Reason of this #earthquake M...     1.0
# 1              Forest fire near La Ronge Sask. Canada     1.0
# 2   All residents asked to 'shelter in place' are ...     1.0
# 3   13,000 people receive #wildfires evacuation or...     1.0
# 4   Just got sent this photo from Ruby #Alaska as ...     1.0
# 5   #RockyFire Update => California Hwy. 20 closed...     1.0
# 6   #flood #disaster Heavy rain causes flash flood...     1.0
# 7   I'm on top of the hill and I can see a fire in...     1.0
# 8   There's an emergency evacuation happening now ...     1.0
# 9   I'm afraid that the tornado is coming to our a...     1.0
# 10        Three people died from the heat wave so far     1.0
# 11  Haha South Tampa is getting flooded hah- WAIT ...     1.0
# 12  #raining #flooding #Florida #TampaBay #Tampa 1...     1.0
# 13            #Flood in Bago Myanmar #We arrived Bago     1.0
# 14  Damage to school bus on 80 in multi car crash ...     1.0
# 15                                     What's up man?     0.0
# 16                                      I love fruits     0.0
# 17                                   Summer is lovely     0.0
# 18                                  My car is so fast     0.0
# 19                       What a goooooooaaaaaal!!!!!!     0.0
# 20                             this is ridiculous....     0.0
# 21                                  London is cool ;)     0.0
# 22                                        Love skiing     0.0
# 23                              What a wonderful day!     0.0
# 24                                           LOOOOOOL     0.0
# 25                     No way...I can't eat that shit     0.0
# 26                              Was in NYC last week!     0.0
# 27                                 Love my girlfriend     0.0
# 28                                          Cooool :)     0.0
# 29                                 Do you like pasta?     0.0
# 30                                           The end!     0.0
# 31  @bbcmtd Wholesale Markets ablaze http://t.co/l...     1.0
# 32  We always try to bring the heavy. #metal #RT h...     0.0
# 33  #AFRICANBAZE: Breaking news:Nigeria flag set a...     1.0
# 34                 Crying out for more! Set me ablaze     0.0
# 35  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...     0.0
# 36  @PhDSquares #mufc they've built so much hype a...     0.0
# 37  INEC Office in Abia Set Ablaze - http://t.co/3...     1.0
# 38  Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...     1.0
# 39                             Ablaze for you Lord :D     0.0
# 40  on the outside you're ablaze and alive\r\nbut ...     0.0
# 41  Had an awesome time visiting the CFC head offi...     0.0
# 42       SOOOO PUMPED FOR ABLAZE ???? @southridgelife     0.0
# 43  I wanted to set Chicago ablaze with my preachi...     0.0
# 44  I gained 3 followers in the last week. You? Kn...     0.0
# 45  How the West was burned: Thousands of wildfire...     1.0
# 46  Building the perfect tracklist to life leave t...     0.0
# 47  First night with retainers in. It's quite weir...     0.0
# 48  Deputies: Man shot before Brighton home set ab...     1.0
# 49  Man wife get six years jail for setting ablaze...     1.0

# %%
for i in range(len(df)):
    df["text"][i] = re.sub('(http|ftp|https)://([\w+?\.\w+])+([a-zA-Z0-9\~\!\@\#$\%\^\&\*_\-\=\+\\/\?\.\:\;\'\,]*)?', '', df["text"][i])
   
df.head()
# Out:
#    keyword  location                                               text  \
# 0      221  no_{col}  Our Deeds are the Reason of this #earthquake M...
# 1      221  no_{col}             Forest fire near La Ronge Sask. Canada
# 2      221  no_{col}  All residents asked to 'shelter in place' are ...
# 3      221  no_{col}  13,000 people receive #wildfires evacuation or...
# 4      221  no_{col}  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
for i in range(len(df)):
    df["text"][i] = re.sub('RT', '', df["text"][i])
    
df.head()
# Out:
#    keyword  location                                               text  \
# 0      221  no_{col}  Our Deeds are the Reason of this #earthquake M...
# 1      221  no_{col}             Forest fire near La Ronge Sask. Canada
# 2      221  no_{col}  All residents asked to 'shelter in place' are ...
# 3      221  no_{col}  13,000 people receive #wildfires evacuation or...
# 4      221  no_{col}  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
for i in range(len(df)):
    df["text"][i] = re.sub('[^a-zA-Z]', ' ', df["text"][i])
    
df.head(50)
# Out:
#     keyword                       location  \
# 0       221                       no_{col}
# 1       221                       no_{col}
# 2       221                       no_{col}
# 3       221                       no_{col}
# 4       221                       no_{col}
# 5       221                       no_{col}
# 6       221                       no_{col}
# 7       221                       no_{col}
# 8       221                       no_{col}
# 9       221                       no_{col}
# 10      221                       no_{col}
# 11      221                       no_{col}
# 12      221                       no_{col}
# 13      221                       no_{col}
# 14      221                       no_{col}
# 15      221                       no_{col}
# 16      221                       no_{col}
# 17      221                       no_{col}
# 18      221                       no_{col}
# 19      221                       no_{col}
# 20      221                       no_{col}
# 21      221                       no_{col}
# 22      221                       no_{col}
# 23      221                       no_{col}
# 24      221                       no_{col}
# 25      221                       no_{col}
# 26      221                       no_{col}
# 27      221                       no_{col}
# 28      221                       no_{col}
# 29      221                       no_{col}
# 30      221                       no_{col}
# 31        0                     Birmingham
# 32        0  Est. September 2012 - Bristol
# 33        0                         AFRICA
# 34        0               Philadelphia, PA
# 35        0                             UK
# 36        0                       Pretoria
# 37        0                   World Wide!!
# 38        0                       no_{col}
# 39        0                 Paranaque City
# 40        0                       no_{col}
# 41        0                      milky way
# 42        0                       no_{col}
# 43        0                       no_{col}
# 44        0                       no_{col}
# 45        0      GREENSBORO,NORTH CAROLINA
# 46        0                       no_{col}
# 47        0                       England.
# 48        0       Sheffield Township, Ohio
# 49        0                          India
#
#                                                  text  target
# 0   Our Deeds are the Reason of this  earthquake M...     1.0
# 1              Forest fire near La Ronge Sask  Canada     1.0
# 2   All residents asked to  shelter in place  are ...     1.0
# 3          people receive  wildfires evacuation or...     1.0
# 4   Just got sent this photo from Ruby  Alaska as ...     1.0
# 5    RockyFire Update    California Hwy     closed...     1.0
# 6    flood  disaster Heavy rain causes flash flood...     1.0
# 7   I m on top of the hill and I can see a fire in...     1.0
# 8   There s an emergency evacuation happening now ...     1.0
# 9   I m afraid that the tornado is coming to our a...     1.0
# 10        Three people died from the heat wave so far     1.0
# 11  Haha South Tampa is getting flooded hah  WAIT ...     1.0
# 12   raining  flooding  Florida  TampaBay  Tampa  ...     1.0
# 13             Flood in Bago Myanmar  We arrived Bago     1.0
# 14  Damage to school bus on    in multi car crash ...     1.0
# 15                                     What s up man      0.0
# 16                                      I love fruits     0.0
# 17                                   Summer is lovely     0.0
# 18                                  My car is so fast     0.0
# 19                       What a goooooooaaaaaal           0.0
# 20                             this is ridiculous         0.0
# 21                                  London is cool        0.0
# 22                                        Love skiing     0.0
# 23                              What a wonderful day      0.0
# 24                                           LOOOOOOL     0.0
# 25                     No way   I can t eat that shit     0.0
# 26                              Was in NYC last week      0.0
# 27                                 Love my girlfriend     0.0
# 28                                          Cooool        0.0
# 29                                 Do you like pasta      0.0
# 30                                           The end      0.0
# 31                   bbcmtd Wholesale Markets ablaze      1.0
# 32        We always try to bring the heavy   metal        0.0
# 33   AFRICANBAZE  Breaking news Nigeria flag set a...     1.0
# 34                 Crying out for more  Set me ablaze     0.0
# 35  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...     0.0
# 36   PhDSquares  mufc they ve built so much hype a...     0.0
# 37                  INEC Office in Abia Set Ablaze        1.0
# 38  Barbados  Bridgetown JAMAICA     Two cars set ...     1.0
# 39                             Ablaze for you Lord  D     0.0
# 40  on the outside you re ablaze and alive  but yo...     0.0
# 41  Had an awesome time visiting the CFC head offi...     0.0
# 42       SOOOO PUMPED FOR ABLAZE       southridgelife     0.0
# 43  I wanted to set Chicago ablaze with my preachi...     0.0
# 44  I gained   followers in the last week  You  Kn...     0.0
# 45  How the West was burned  Thousands of wildfire...     1.0
# 46  Building the perfect tracklist to life leave t...     0.0
# 47  First night with retainers in  It s quite weir...     0.0
# 48  Deputies  Man shot before Brighton home set ab...     1.0
# 49  Man wife get six years jail for setting ablaze...     1.0

# %%
df['text'] = df['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df.head()
# Out:
#    keyword  location                                               text  \
# 0      221  no_{col}  our deeds are the reason of this earthquake ma...
# 1      221  no_{col}              forest fire near la ronge sask canada
# 2      221  no_{col}  all residents asked to shelter in place are be...
# 3      221  no_{col}  people receive wildfires evacuation orders in ...
# 4      221  no_{col}  just got sent this photo from ruby alaska as s...
#
#    target
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
sw = stopwords.words('english')
sw
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kalac\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
df['text'] = df['text'].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

# %%
df.head(7000)
# Out:
#       keyword                location  \
# 0         221                no_{col}
# 1         221                no_{col}
# 2         221                no_{col}
# 3         221                no_{col}
# 4         221                no_{col}
# ...       ...                     ...
# 6995      209                   The D
# 6996      209  Still. ??S.A.N.D.O.S??
# 6997      209                no_{col}
# 6998      209      We're All Mad Here
# 6999      209     Southern California
#
#                                                    text  target
# 0          deeds reason earthquake may allah forgive us     1.0
# 1                 forest fire near la ronge sask canada     1.0
# 2     residents asked shelter place notified officer...     1.0
# 3     people receive wildfires evacuation orders cal...     1.0
# 4     got sent photo ruby alaska smoke wildfires pou...     1.0
# ...                                                 ...     ...
# 6995  debatequestionswewanttohear u start another wa...     1.0
# 6996  mama still thuggin world war zone homies inmat...     0.0
# 6997  worldwatchesferguson florida govjaynixon clair...     1.0
# 6998            packing ct aka room looks like war zone     0.0
# 6999  kasiakosek drive sucks case know desk looks li...     0.0
#
# [7000 rows x 4 columns]

# %%
least = pd.Series(" ".join(df["text"]).split()).value_counts().reset_index()
least.columns = ['words', 'tf']
least.head()
# Out:
#   words   tf
# 0   amp  506
# 1  like  487
# 2  fire  357
# 3   get  337
# 4   new  329

# %%
sil = least[least["tf"] < 50]
sil
# Out:
#             words  tf
# 367      derailed  49
# 368    obliterate  49
# 369      wreckage  49
# 370       rioting  49
# 371       twister  49
# ...           ...  ..
# 20077      zipped   1
# 20078       strap   1
# 20079        lenn   1
# 20080        ddnt   1
# 20081        xrwn   1
#
# [19715 rows x 2 columns]

# %%
df['text'] = df['text'].apply(lambda x: " ".join(x for x in x.split() if x not in sil))

# %%
from textblob import Word
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
df['text'] = df['text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kalac\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kalac\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df[:20]
# Out:
#     keyword  location                                               text  \
# 0       221  no_{col}         deed reason earthquake may allah forgive u
# 1       221  no_{col}              forest fire near la ronge sask canada
# 2       221  no_{col}  resident asked shelter place notified officer ...
# 3       221  no_{col}  people receive wildfire evacuation order calif...
# 4       221  no_{col}  got sent photo ruby alaska smoke wildfire pour...
# 5       221  no_{col}  rockyfire update california hwy closed directi...
# 6       221  no_{col}  flood disaster heavy rain cause flash flooding...
# 7       221  no_{col}                             top hill see fire wood
# 8       221  no_{col}  emergency evacuation happening building across...
# 9       221  no_{col}                         afraid tornado coming area
# 10      221  no_{col}                    three people died heat wave far
# 11      221  no_{col}  haha south tampa getting flooded hah wait seco...
# 12      221  no_{col}  raining flooding florida tampabay tampa day lo...
# 13      221  no_{col}                    flood bago myanmar arrived bago
# 14      221  no_{col}         damage school bus multi car crash breaking
# 15      221  no_{col}                                                man
# 16      221  no_{col}                                         love fruit
# 17      221  no_{col}                                      summer lovely
# 18      221  no_{col}                                           car fast
# 19      221  no_{col}                                    goooooooaaaaaal
#
#     target
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      1.0
# 8      1.0
# 9      1.0
# 10     1.0
# 11     1.0
# 12     1.0
# 13     1.0
# 14     1.0
# 15     0.0
# 16     0.0
# 17     0.0
# 18     0.0
# 19     0.0

# %%
tf1 = pd.Series(' '.join(df['text']).lower().split()).value_counts().reset_index()
tf1.columns = ['words', 'tf']

# %%
tf1.head()
# Out:
#   words   tf
# 0  fire  511
# 1   amp  506
# 2  like  490
# 3   get  382
# 4     u  373

# %%
tf1[:30].plot.bar(x="words", y="tf", figsize=(15,4), color="pink");
plt.title('Most used words in tweets');

# %%
non_disaster_tweets_count = Counter(" ".join(df[df['target']==0]["text"]).split()).most_common(20)
non_disaster_tweets_count_df = pd.DataFrame(non_disaster_tweets_count, columns=["words", "freq"])
print("The 20 most used words in non-disaster tweets:")
non_disaster_tweets_count_df
# Out:
# The 20 most used words in non-disaster tweets:
#      words  freq
# 0     like   254
# 1      amp   207
# 2      get   185
# 3      new   171
# 4        u   155
# 5      one   139
# 6     body   119
# 7     time   106
# 8      day   104
# 9    video   101
# 10   would    99
# 11     via    97
# 12    love    96
# 13      go    92
# 14  people    92
# 15    know    91
# 16    fire    88
# 17    back    86
# 18     got    85
# 19     see    84

# %%
non_disaster_tweets_count_df.plot.bar(x="words", y="freq", figsize=(21,7), color="plum")
plt.title('The most used words in non-disaster tweets')
plt.xlabel('Words')
plt.ylabel('Frequency of Use');

# %%
disaster_tweets_count = Counter(" ".join(df[df['target']==1]["text"]).split()).most_common(20)
disaster_tweets_count_df = pd.DataFrame(disaster_tweets_count, columns=["words", "freq"])
print("The 20 most used words in disaster-related tweets:")
disaster_tweets_count_df
# Out:
# The 20 most used words in disaster-related tweets:
#          words  freq
# 0         fire   256
# 1         news   147
# 2          amp   133
# 3          via   117
# 4   california   113
# 5     disaster   112
# 6            u   110
# 7       police   106
# 8      suicide   104
# 9       people   102
# 10        home   101
# 11      family    99
# 12      killed    95
# 13       storm    95
# 14   hiroshima    92
# 15       crash    90
# 16        year    90
# 17        like    90
# 18       train    89
# 19        bomb    86

# %%
disaster_tweets_count_df.plot.bar(x="words", y="freq", figsize=(21,7), color="purple")
plt.title('The most used words in disaster-related tweets')
plt.xlabel('Words')
plt.ylabel('Frequency of Use');

# %% [markdown]
# # Train - Test

# %%
y = df.target[:len(df_test)]
X = df.drop(["target","location"],axis=1)[:len(df_test)]

# %%
X, y
# Out:
# (      keyword                                               text
#  0         221         deed reason earthquake may allah forgive u
#  1         221              forest fire near la ronge sask canada
#  2         221  resident asked shelter place notified officer ...
#  3         221  people receive wildfire evacuation order calif...
#  4         221  got sent photo ruby alaska smoke wildfire pour...
#  ...       ...                                                ...
#  3258       96  rocky fire northern california swell acre evac...
#  3259       96  trafford centre film fan angry odeon cinema ev...
#  3260       96   dead missing family evacuated due flood bukidnon
#  3261       96  missleylaha get buy one last london show fire ...
#  3262       96  got evacuated movie theatre emergency saw peop...
#
#  [3263 rows x 2 columns],
#  0       1.0
#  1       1.0
#  2       1.0
#  3       1.0
#  4       1.0
#         ...
#  3258    1.0
#  3259    1.0
#  3260    1.0
#  3261    0.0
#  3262    1.0
#  Name: target, Length: 3263, dtype: float64)

# %%
X_train, X_test , y_train, y_test = model_selection.train_test_split(X, y, random_state=42, test_size=0.30)
X_train.head()
# Out:
#       keyword                                               text
# 1556       45  lower striked would gone even otm could really...
# 435        11  owner chicago area gay bar admits arson scheme...
# 1829       53                          starflame girl yeah crush
# 237         6                 evildead annihilation civilization
# 2820       83  karijobe band killed tonight almost loud enoug...

# %% [markdown]
# # Count Vectors

# %%
vectorizer = CountVectorizer()
vectorizer.fit(X_train['text'])
# Out:
# CountVectorizer()

# %%
x_train_count = vectorizer.fit_transform(X_train['text'])
x_test_count = vectorizer.transform(X_test['text'])

# %%
vectorizer.get_feature_names_out()[:5]
# Out:
# array(['aa', 'aaaaaaallll', 'aace', 'aashiqui', 'ab'], dtype=object)

# %% [markdown]
# # # TF-IDF Vectors (words, characters, n-grams)
# # Word Level TF-IDF

# %%
tf_idf_word_vectorizer = TfidfVectorizer()
tf_idf_word_vectorizer.fit(X_train['text'])
x_train_tf_idf_word = tf_idf_word_vectorizer.fit_transform(X_train['text'])
x_test_tf_idf_word = tf_idf_word_vectorizer.transform(X_test['text'])

# %%
tf_idf_word_vectorizer.get_feature_names_out()[:5]
# Out:
# array(['aa', 'aaaaaaallll', 'aace', 'aashiqui', 'ab'], dtype=object)

# %% [markdown]
# # Ngram Level TF-IDF

# %%
tf_idf_ngram_vectorizer = TfidfVectorizer(ngram_range = (2,3))
tf_idf_ngram_vectorizer.fit(X_train['text'])
x_train_tf_idf_ngarm = tf_idf_ngram_vectorizer.fit_transform(X_train['text'])
x_test_tf_idf_ngram = tf_idf_ngram_vectorizer.transform(X_test['text'])

# %%
tf_idf_ngram_vectorizer.get_feature_names_out()[:5]
# Out:
# array(['aa battery', 'aa battery swear', 'aa mgm', 'aa mgm grand',
#        'aaaaaaallll even'], dtype=object)

# %% [markdown]
# # Characters level TF-IDF

# %%
tf_idf_chars_vectorizer = TfidfVectorizer(analyzer = "char", ngram_range = (2,3))
tf_idf_chars_vectorizer.fit(X_train['text'])
x_train_tf_idf_chars = tf_idf_chars_vectorizer.fit_transform(X_train['text'])
x_test_tf_idf_chars = tf_idf_chars_vectorizer.transform(X_test['text'])

# %%
tf_idf_chars_vectorizer.get_feature_names_out()[:5]
# Out:
# array([' a', ' aa', ' ab', ' ac', ' ad'], dtype=object)

# %% [markdown]
# # Creating a Model

# %%
all_performances = pd.DataFrame()
list_clf_name = []
list_x_test = []
list_pred = []
list_model = []

# %%
def fit_model(model, x_train_x, y_train):
    x_model = model.fit(x_train_x,y_train)
    return x_model

# %%
def model_name(model, vector_name):
    model_name = model.__class__.__name__
    suffix = ""
    
    if vector_name == "c":
        suffix = "_count"
    elif vector_name == "n":
        suffix = "_ngram"
    elif vector_name == "w":
        suffix = "_word"
    elif vector_name == "ch":
        suffix = "_chars"

    if "_tuned" in vector_name:  # Explicitly check for tuning
        return f"{model_name}{suffix}_tuned"
    
    return f"{model_name}{suffix}"

# %%
def add_list(name, model, x_test_x, y_pred):
    global list_clf_name, list_pred, list_model, list_x_test
    list_clf_name.append(name)
    list_model.append(model)
    list_x_test.append(x_test_x)
    list_pred.append(y_pred)

# %%
def add_all_performances(name, training_set_score, test_set_score, precision, recall, f1_score, AUC):
    global all_performances
    models = pd.DataFrame([[name, training_set_score, test_set_score, precision, recall, f1_score, AUC]],
                         columns=["model_name","training_set_score", "test_set_score",
                                  "precision", "recall", "f1_score", "AUC"])
    all_performances = pd.concat([all_performances, models], ignore_index=True)
    all_performances= all_performances.drop_duplicates()

# %%
def model_performance(x_train_x, x_test_x, model, vector_name):
    
    x_model = fit_model(model, x_train_x, y_train)
    
    name = model_name(model, vector_name)
    y_pred = x_model.predict(x_test_x)
    training_set_score= x_model.score(x_train_x, y_train)
    test_set_score = x_model.score(x_test_x, y_test)
    precision = mt.precision_score(y_test,y_pred)
    recall = mt.recall_score(y_test,y_pred)
    f1_score= mt.f1_score(y_test, y_pred)
    AUC = roc_auc_score(y_test, y_pred) 
    
    add_list(name, model, x_test_x, y_pred)
    add_all_performances(name, training_set_score, test_set_score, precision, recall, f1_score, AUC)
    
    print(classification_report(y_test, y_pred, target_names=['non-disaster','disaster']))

# %% [markdown]
# # Logistic Regression

# %%
log_reg = linear_model.LogisticRegression()
model_performance(x_train_count, x_test_count, log_reg, "c")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.79      0.91      0.84       581
#     disaster       0.82      0.64      0.72       398
#
#     accuracy                           0.80       979
#    macro avg       0.80      0.77      0.78       979
# weighted avg       0.80      0.80      0.79       979

# %%
log_reg = linear_model.LogisticRegression()
model_performance(x_train_tf_idf_word, x_test_tf_idf_word, log_reg, "w")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.76      0.95      0.85       581
#     disaster       0.88      0.57      0.70       398
#
#     accuracy                           0.80       979
#    macro avg       0.82      0.76      0.77       979
# weighted avg       0.81      0.80      0.78       979

# %%
log_reg = linear_model.LogisticRegression()
model_performance(x_train_tf_idf_ngarm, x_test_tf_idf_ngram, log_reg, "n")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.66      0.98      0.79       581
#     disaster       0.92      0.26      0.40       398
#
#     accuracy                           0.69       979
#    macro avg       0.79      0.62      0.60       979
# weighted avg       0.77      0.69      0.63       979

# %%
log_reg = linear_model.LogisticRegression()
model_performance(x_train_tf_idf_chars, x_test_tf_idf_chars, log_reg, "ch")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.75      0.90      0.82       581
#     disaster       0.79      0.56      0.66       398
#
#     accuracy                           0.76       979
#    macro avg       0.77      0.73      0.74       979
# weighted avg       0.76      0.76      0.75       979

# %% [markdown]
# # Naive Bayes

# %%
from sklearn import naive_bayes
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = model_selection.train_test_split(X, y, random_state=42, test_size=0.30)
nb = naive_bayes.MultinomialNB()
nb.fit(x_train_count,x_test_count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 5
#       3 X_train, X_test , y_train, y_test = model_selection.train_test_split(X, y, random_state=42, test_size=0.30)
#       4 nb = naive_bayes.MultinomialNB()
# ----> 5 nb.fit(x_train_count,x_test_count)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:732, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     711 @_fit_context(prefer_skip_nested_validation=True)
#     712 def fit(self, X, y, sample_weight=None):
#     713     """Fit Naive Bayes classifier according to X, y.
#     714
#     715     Parameters
#    (...)
#     730         Returns the instance itself.
#     731     """
# --> 732     X, y = self._check_X_y(X, y)
#     733     _, n_features = X.shape
#     735     labelbin = LabelBinarizer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:578, in _BaseDiscreteNB._check_X_y(self, X, y, reset)
#     576 def _check_X_y(self, X, y, reset=True):
#     577     """Validate X and y in fit methods."""
# --> 578     return self._validate_data(X, y, accept_sparse="csr", reset=reset)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1318, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
#    1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    (...)
#    1315     input_name="X",
#    1316 )
# -> 1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#    1322 return X, y
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339, in _check_y(y, multi_output, y_numeric, estimator)
#    1337 else:
#    1338     estimator_name = _check_estimator_name(estimator)
# -> 1339     y = column_or_1d(y, warn=True)
#    1340     _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#    1341     _ensure_no_complex_data(y)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1381, in column_or_1d(y, dtype, warn)
#    1349 """Ravel column or 1d numpy array, else raises an error.
#    1350
#    1351 Parameters
#    (...)
#    1378 array([1, 1])
#    1379 """
#    1380 xp, _ = get_namespace(y)
# -> 1381 y = check_array(
#    1382     y,
#    1383     ensure_2d=False,
#    1384     dtype=dtype,
#    1385     input_name="y",
#    1386     force_all_finite=False,
#    1387     ensure_min_samples=0,
#    1388 )
#    1390 shape = y.shape
#    1391 if len(shape) == 1:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:971, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     969 if sp.issparse(array):
#     970     _ensure_no_complex_data(array)
# --> 971     array = _ensure_sparse_format(
#     972         array,
#     973         accept_sparse=accept_sparse,
#     974         dtype=dtype,
#     975         copy=copy,
#     976         force_all_finite=force_all_finite,
#     977         accept_large_sparse=accept_large_sparse,
#     978         estimator_name=estimator_name,
#     979         input_name=input_name,
#     980     )
#     981     if ensure_2d and array.ndim < 2:
#     982         raise ValueError(
#     983             f"Expected 2D input, got input with shape {array.shape}.\n"
#     984             "Reshape your data either using array.reshape(-1, 1) if "
#     985             "your data has a single feature or array.reshape(1, -1) "
#     986             "if it contains a single sample."
#     987         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:595, in _ensure_sparse_format(sparse_container, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     593 if accept_sparse is False:
#     594     padded_input = " for " + input_name if input_name else ""
# --> 595     raise TypeError(
#     596         f"Sparse data was passed{padded_input}, but dense data is required. "
#     597         "Use '.toarray()' to convert to a dense numpy array."
#     598     )
#     599 elif isinstance(accept_sparse, (list, tuple)):
#     600     if len(accept_sparse) == 0:
#
# TypeError: Sparse data was passed for y, but dense data is required. Use '.toarray()' to convert to a dense numpy array.

# %%
nb = naive_bayes.MultinomialNB()
model_performance(x_train_count, x_test_count, nb, "c")

# %%
nb = naive_bayes.MultinomialNB()
model_performance(x_train_tf_idf_word, x_test_tf_idf_word, nb, "w")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.76      0.94      0.84       581
#     disaster       0.87      0.56      0.68       398
#
#     accuracy                           0.79       979
#    macro avg       0.82      0.75      0.76       979
# weighted avg       0.80      0.79      0.78       979

# %%
nb = naive_bayes.MultinomialNB()
model_performance(x_train_tf_idf_ngarm, x_test_tf_idf_ngram, nb, "n")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.70      0.97      0.81       581
#     disaster       0.91      0.38      0.54       398
#
#     accuracy                           0.73       979
#    macro avg       0.80      0.68      0.68       979
# weighted avg       0.78      0.73      0.70       979

# %%
nb = naive_bayes.MultinomialNB()
model_performance(x_train_tf_idf_chars, x_test_tf_idf_chars, nb, "ch")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.64      1.00      0.78       581
#     disaster       0.97      0.17      0.28       398
#
#     accuracy                           0.66       979
#    macro avg       0.80      0.58      0.53       979
# weighted avg       0.77      0.66      0.58       979

# %% [markdown]
# # Random Forests

# %%
rf = ensemble.RandomForestClassifier()
model_performance(x_train_count, x_test_count, rf, "c")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.76      0.92      0.84       581
#     disaster       0.84      0.59      0.69       398
#
#     accuracy                           0.79       979
#    macro avg       0.80      0.75      0.76       979
# weighted avg       0.79      0.79      0.78       979

# %%
rf = ensemble.RandomForestClassifier()
model_performance(x_train_tf_idf_word, x_test_tf_idf_word, rf, "w")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.74      0.93      0.82       581
#     disaster       0.83      0.52      0.64       398
#
#     accuracy                           0.76       979
#    macro avg       0.78      0.72      0.73       979
# weighted avg       0.77      0.76      0.75       979

# %%
rf = ensemble.RandomForestClassifier()
model_performance(x_train_tf_idf_ngarm, x_test_tf_idf_ngram, rf, "n")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.65      0.98      0.78       581
#     disaster       0.89      0.22      0.36       398
#
#     accuracy                           0.67       979
#    macro avg       0.77      0.60      0.57       979
# weighted avg       0.75      0.67      0.61       979

# %%
rf = ensemble.RandomForestClassifier()
model_performance(x_train_tf_idf_chars, x_test_tf_idf_chars, rf, "ch")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.73      0.91      0.81       581
#     disaster       0.79      0.52      0.63       398
#
#     accuracy                           0.75       979
#    macro avg       0.76      0.71      0.72       979
# weighted avg       0.76      0.75      0.74       979

# %% [markdown]
# # XGBoost

# %%
xgb = xgboost.XGBClassifier()
model_performance(x_train_count, x_test_count, xgb, "c")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.77      0.90      0.83       581
#     disaster       0.80      0.61      0.69       398
#
#     accuracy                           0.78       979
#    macro avg       0.78      0.75      0.76       979
# weighted avg       0.78      0.78      0.77       979

# %%
xgb = xgboost.XGBClassifier()
model_performance(x_train_tf_idf_word, x_test_tf_idf_word, xgb, "w")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.74      0.90      0.81       581
#     disaster       0.79      0.53      0.64       398
#
#     accuracy                           0.75       979
#    macro avg       0.76      0.72      0.72       979
# weighted avg       0.76      0.75      0.74       979

# %%
xgb = xgboost.XGBClassifier()
model_performance(x_train_tf_idf_ngarm, x_test_tf_idf_ngram, xgb, "n")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.64      0.97      0.77       581
#     disaster       0.85      0.21      0.33       398
#
#     accuracy                           0.66       979
#    macro avg       0.74      0.59      0.55       979
# weighted avg       0.72      0.66      0.59       979

# %%
xgb = xgboost.XGBClassifier()
model_performance(x_train_tf_idf_chars, x_test_tf_idf_chars, xgb, "ch")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.75      0.82      0.79       581
#     disaster       0.70      0.61      0.65       398
#
#     accuracy                           0.73       979
#    macro avg       0.73      0.71      0.72       979
# weighted avg       0.73      0.73      0.73       979

# %% [markdown]
# # Performance Evaluation

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_auc_score

def display_all_confusion_matrix():
    num_classifiers = len(list_clf_name)
    cols = 4
    rows = -(-num_classifiers // cols)
    
    f, ax = plt.subplots(rows, cols, figsize=(20, rows * 5), sharey='row')
    ax = ax.flatten()

    for i in range(len(list_clf_name)):
        cf_matrix = confusion_matrix(y_test, list_pred[i])
        disp = ConfusionMatrixDisplay(cf_matrix)
        disp.plot(ax=ax[i], xticks_rotation=45)
        disp.ax_.set_title(list_clf_name[i]+"\nAccuracy:{accuracy:.4f}\nAUC:{auc:.4f}"
                           .format(accuracy= accuracy_score(y_test, list_pred[i]),auc= roc_auc_score(y_test, list_pred[i])),
                             fontsize=14)
        disp.im_.colorbar.remove()
        disp.ax_.set_xlabel('')
        if i!=0:
            disp.ax_.set_ylabel('')


    for j in range(num_classifiers, len(ax)):
        f.delaxes(ax[j])

    f.text(0.5, 0.04, 'Predicted label', ha='center', fontsize=16)
    f.text(0.04, 0.5, 'True label', va='center', rotation='vertical', fontsize=16)
    plt.subplots_adjust(hspace=0.4, wspace=0.3)

    cbar_ax = f.add_axes([0.92, 0.15, 0.02, 0.7])
    f.colorbar(disp.im_, cax=cbar_ax)
    plt.show()

# %%
display_all_confusion_matrix()

# %%
all_performances.sort_values(by=['f1_score'], ascending=False)
# Out:
#                       model_name  training_set_score  test_set_score  \
# 4            MultinomialNB_count            0.948336        0.787538
# 0       LogisticRegression_count            0.980298        0.796731
# 1        LogisticRegression_word            0.891856        0.789581
# 12           XGBClassifier_count            0.864711        0.778345
# 8   RandomForestClassifier_count            0.993433        0.785495
# 5             MultinomialNB_word            0.926445        0.787538
# 3       LogisticRegression_chars            0.875219        0.770174
# 15           XGBClassifier_chars            0.999124        0.734423
# 9    RandomForestClassifier_word            1.000000        0.760981
# 13            XGBClassifier_word            0.903240        0.752809
# 11  RandomForestClassifier_chars            1.000000        0.748723
# 6            MultinomialNB_ngram            0.989930        0.733401
# 2       LogisticRegression_ngram            0.852452        0.672114
# 10  RandomForestClassifier_ngram            1.000000        0.673136
# 14           XGBClassifier_ngram            0.769264        0.661900
# 7            MultinomialNB_chars            0.737741        0.658836
#
#     precision    recall  f1_score       AUC
# 4    0.759563  0.698492  0.727749  0.773515
# 0    0.822006  0.638191  0.718529  0.771763
# 1    0.847826  0.587940  0.694362  0.757825
# 12   0.798680  0.608040  0.690442  0.751524
# 8    0.838129  0.585427  0.689349  0.753987
# 5    0.874016  0.557789  0.680982  0.751356
# 3    0.812274  0.565327  0.666667  0.737913
# 15   0.698276  0.610553  0.651475  0.714915
# 9    0.828000  0.520101  0.638889  0.723045
# 13   0.791045  0.532663  0.636637  0.718139
# 11   0.792308  0.517588  0.626140  0.712322
# 6    0.905325  0.384422  0.539683  0.678442
# 2    0.632302  0.462312  0.534107  0.639073
# 10   0.890000  0.223618  0.357430  0.602343
# 14   0.845361  0.206030  0.331313  0.590106
# 7    0.970588  0.165829  0.283262  0.581193

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
plt.xticks(rotation=75)
sns.barplot(x="model_name", y ="f1_score", data = all_performances, ax=ax);
title = plt.title('Performance Table by F1 Score')

# %% [markdown]
# # Hyperparameter Tuning
# # Naive Bayes

# %%
param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 11.25, 11.5, 11.75],
    'fit_prior': [True, False],
    'class_prior': [None, [0.3, 0.7], [0.5, 0.5]]
}

# %%
classifier = naive_bayes.MultinomialNB()

# %%
from sklearn.model_selection import StratifiedKFold

grid_search = GridSearchCV(
    estimator=classifier,
    param_grid=param_grid,
    cv=StratifiedKFold(n_splits=5),
    scoring='f1',
    verbose=2
)

# %% [markdown]
# # Count Vector

# %%
grid_search.fit(x_train_count, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# GridSearchCV(cv=5, estimator=MultinomialNB(),
#              param_grid={'alpha': [11.25, 11.5, 11.75],
#                          'class_prior': [None, [0.3, 0.7], [0.5, 0.5]],
#                          'fit_prior': [True, False]},
#              scoring='accuracy', verbose=2)

# %%
# Print the best parameter combination and score
print("Best Parameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'alpha': 11.75, 'class_prior': None, 'fit_prior': True}
# Best Score:  0.7863334485009021

# %%
best_classifier = grid_search.best_estimator_
accuracy = best_classifier.score(x_test_count, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.7865168539325843

# %% [markdown]
# # Word Level TF-IDF

# %%
grid_search.fit(x_train_tf_idf_word, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.25, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.25, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.25, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .......alpha=11.5, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.5, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END .alpha=11.5, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.5, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END ......alpha=11.75, class_prior=None, fit_prior=True; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END .....alpha=11.75, class_prior=None, fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.3, 0.7], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=True; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# [CV] END alpha=11.75, class_prior=[0.5, 0.5], fit_prior=False; total time=   0.0s
# GridSearchCV(cv=5, estimator=MultinomialNB(),
#              param_grid={'alpha': [11.25, 11.5, 11.75],
#                          'class_prior': [None, [0.3, 0.7], [0.5, 0.5]],
#                          'fit_prior': [True, False]},
#              scoring='accuracy', verbose=2)

# %%
# Print the best parameter combination and score
print("Best Parameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'alpha': 11.25, 'class_prior': None, 'fit_prior': False}
# Best Score:  0.7740853775576797

# %% [markdown]
# C# Logistic Regression (Count Vector)

# %%
param_grid = {
    'C': [0.25,0.3,0.35],  # inverse regularization strength
    'penalty': ['l1', 'l2'],  # regularization type
    'solver': ['liblinear', 'saga']  # optimization algorithm
}

# %%
classifier = linear_model.LogisticRegression()

# %%
# Perform grid search with cross-validation
grid_search = GridSearchCV(
    estimator=classifier,
    param_grid=param_grid,
    cv=5,  # 5-fold cross-validation
    scoring='f1',  # Tune for F1 score
    verbose=2
)
grid_search.fit(x_train_count, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ...............C=0.25, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.25, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.25, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ................C=0.3, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ................C=0.3, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ................C=0.3, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .....................C=0.3, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.35, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ....................C=0.35, penalty=l2, solver=saga; total time=   0.0s
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.25, 0.3, 0.35], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              scoring='f1', verbose=2)

# %%
# Print the best parameter combination and score
print("Best Parameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'C': 0.35, 'penalty': 'l2', 'solver': 'saga'}
# Best Score:  0.6907033891585245

# %% [markdown]
# # Best Performing Model

# %%
best_classifier = grid_search.best_estimator_

# %%
best_classifier
# Out:
# LogisticRegression(C=0.35, solver='saga')

# %%
test_f1_score = f1_score(y_test, best_classifier.predict(x_test_count))
test_accuracy = best_classifier.score(x_test_count, y_test)

print("Test F1 Score:", test_f1_score)
print("Test Accuracy:", test_accuracy)
# Out:
# Test F1 Score: 0.7215909090909091
# Test Accuracy: 0.7997957099080695

# %%
model_performance(x_train_count, x_test_count, best_classifier, "c_tuned")
# Out:
#               precision    recall  f1-score   support
#
# non-disaster       0.78      0.91      0.84       581
#     disaster       0.83      0.64      0.72       398
#
#     accuracy                           0.80       979
#    macro avg       0.81      0.77      0.78       979
# weighted avg       0.80      0.80      0.79       979

# %%
all_performances.sort_values(by=['f1_score'], ascending=False)
# Out:
#                       model_name  training_set_score  test_set_score  \
# 4            MultinomialNB_count            0.948336        0.787538
# 16      LogisticRegression_tuned            0.947898        0.798774
# 0       LogisticRegression_count            0.980298        0.796731
# 1        LogisticRegression_word            0.891856        0.789581
# 12           XGBClassifier_count            0.864711        0.778345
# 8   RandomForestClassifier_count            0.993433        0.785495
# 5             MultinomialNB_word            0.926445        0.787538
# 3       LogisticRegression_chars            0.875219        0.770174
# 15           XGBClassifier_chars            0.999124        0.734423
# 9    RandomForestClassifier_word            1.000000        0.760981
# 13            XGBClassifier_word            0.903240        0.752809
# 11  RandomForestClassifier_chars            1.000000        0.748723
# 6            MultinomialNB_ngram            0.989930        0.733401
# 2       LogisticRegression_ngram            0.852452        0.672114
# 10  RandomForestClassifier_ngram            1.000000        0.673136
# 14           XGBClassifier_ngram            0.769264        0.661900
# 7            MultinomialNB_chars            0.737741        0.658836
#
#     precision    recall  f1_score       AUC
# 4    0.759563  0.698492  0.727749  0.773515
# 16   0.829508  0.635678  0.719772  0.773089
# 0    0.822006  0.638191  0.718529  0.771763
# 1    0.847826  0.587940  0.694362  0.757825
# 12   0.798680  0.608040  0.690442  0.751524
# 8    0.838129  0.585427  0.689349  0.753987
# 5    0.874016  0.557789  0.680982  0.751356
# 3    0.812274  0.565327  0.666667  0.737913
# 15   0.698276  0.610553  0.651475  0.714915
# 9    0.828000  0.520101  0.638889  0.723045
# 13   0.791045  0.532663  0.636637  0.718139
# 11   0.792308  0.517588  0.626140  0.712322
# 6    0.905325  0.384422  0.539683  0.678442
# 2    0.632302  0.462312  0.534107  0.639073
# 10   0.890000  0.223618  0.357430  0.602343
# 14   0.845361  0.206030  0.331313  0.590106
# 7    0.970588  0.165829  0.283262  0.581193

# %%
df
# Out:
#        keyword  location                                               text  \
# 0          221  no_{col}        deed reason #earthquake may allah forgive u
# 1          221  no_{col}             forest fire near la ronge sask. canada
# 2          221  no_{col}  resident asked 'shelter place' notified office...
# 3          221  no_{col}  13,000 people receive #wildfires evacuation or...
# 4          221  no_{col}  got sent photo ruby #alaska smoke #wildfires p...
# ...        ...       ...                                                ...
# 10692      221  no_{col}  earthquake safety los angeles ûò safety faste...
# 10693      221  no_{col}  storm ri worse last hurricane. city&amp;3other...
# 10694      221  no_{col}  green line derailment chicago http://t.co/utbx...
# 10695      221  no_{col}  meg issue hazardous weather outlook (hwo) http...
# 10696      221  no_{col}  #cityofcalgary activated municipal emergency p...
#
#        target
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
# ...       ...
# 10692     NaN
# 10693     NaN
# 10694     NaN
# 10695     NaN
# 10696     NaN
#
# [10697 rows x 4 columns]

# %%
X_pred = df[len(df_train):].drop("target",axis=1)
X_pred["text"]
# Out:
# 7434                           happened terrible car crash
# 7435     heard #earthquake different cities, stay safe ...
# 7436     forest fire spot pond, goose fleeing across st...
# 7437              apocalypse lighting. #spokane #wildfires
# 7438                 typhoon soudelor kill 28 china taiwan
#                                ...
# 10692    earthquake safety los angeles ûò safety faste...
# 10693    storm ri worse last hurricane. city&amp;3other...
# 10694    green line derailment chicago http://t.co/utbx...
# 10695    meg issue hazardous weather outlook (hwo) http...
# 10696    #cityofcalgary activated municipal emergency p...
# Name: text, Length: 3263, dtype: object

# %%
X_train['text']
# Out:
# 1556    627% lower striked 16 would gone even otm. cou...
# 435     owner chicago-area gay bar admits arson scheme...
# 1829                           @starflame_girl yeah crush
# 237     evildead - annihilation civilization http://t....
# 2820    .@karijobe band killed tonight. almost loud en...
#                               ...
# 1095    'the third generation atomic bombed survivor' ...
# 1130    70th anniversary hiroshima atomic bombing mark...
# 1294    parent taking kid burning man one 11 year old ...
# 860     man . somebody gotta stop sbee dude fuckin fun...
# 3174          @fnaf_talkmc *stands engulfed fire smiling*
# Name: text, Length: 2284, dtype: object

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(X_train['text'])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 24803 stored elements and shape (2284, 8756)>

# %%
X_pred_count = vectorizer.transform(X_pred["text"])

# %%
vectorizer.get_feature_names_out()[:5]
# Out:
# array(['00', '000', '007npen6lg', '01', '02pm'], dtype=object)

# %%
y_pred = best_classifier.predict(X_pred_count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[290], line 1
# ----> 1 y_pred = best_classifier.predict(X_pred_count)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:382, in LinearClassifierMixin.predict(self, X)
#     368 """
#     369 Predict class labels for samples in X.
#     370
#    (...)
#     379     Vector containing the class labels for each sample.
#     380 """
#     381 xp, _ = get_namespace(X)
# --> 382 scores = self.decision_function(X)
#     383 if len(scores.shape) == 1:
#     384     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:363, in LinearClassifierMixin.decision_function(self, X)
#     360 check_is_fitted(self)
#     361 xp, _ = get_namespace(X)
# --> 363 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     364 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     365 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 8756 features, but LogisticRegression is expecting 6819 features as input.

# %%
data = {'tweet': X_pred["text"], 'location': X_pred['location'] , 'predicted_label': y_pred}
predicted_data = pd.DataFrame(data).reset_index(drop=True)

# %%
predicted_data['actual_label'] = sample_submission["target"].reset_index(drop=True)

# %%
predicted_data
# Out:
#                                                   tweet  location  \
# 0                           happened terrible car crash  no_{col}
# 1     heard #earthquake different cities, stay safe ...  no_{col}
# 2     forest fire spot pond, goose fleeing across st...  no_{col}
# 3              apocalypse lighting. #spokane #wildfires  no_{col}
# 4                 typhoon soudelor kill 28 china taiwan  no_{col}
# ...                                                 ...       ...
# 3258  earthquake safety los angeles ûò safety faste...  no_{col}
# 3259  storm ri worse last hurricane. city&amp;3other...  no_{col}
# 3260  green line derailment chicago http://t.co/utbx...  no_{col}
# 3261  meg issue hazardous weather outlook (hwo) http...  no_{col}
# 3262  #cityofcalgary activated municipal emergency p...  no_{col}
#
#       predicted_label  actual_label
# 0                 0.0             0
# 1                 1.0             0
# 2                 1.0             0
# 3                 0.0             0
# 4                 0.0             0
# ...               ...           ...
# 3258              0.0             0
# 3259              1.0             0
# 3260              1.0             0
# 3261              0.0             0
# 3262              0.0             0
#
# [3263 rows x 4 columns]

# %%
sample_submission["target"].unique()
# Out:
# array([0], dtype=int64)

# %%
right_predictions = predicted_data[(predicted_data["predicted_label"] == predicted_data["actual_label"])]
right_predictions = right_predictions.reset_index(drop=True)
right_predictions
# Out:
#                                                   tweet  location  \
# 0                           happened terrible car crash  no_{col}
# 1              apocalypse lighting. #spokane #wildfires  no_{col}
# 2                 typhoon soudelor kill 28 china taiwan  no_{col}
# 3     they'd probably still show life arsenal yester...  no_{col}
# 4                                             hey! you?  no_{col}
# ...                                                 ...       ...
# 2428  see 16yr old pkk suicide bomber detonated bomb...  no_{col}
# 2429  conference attendees! blue line airport derail...  no_{col}
# 2430  earthquake safety los angeles ûò safety faste...  no_{col}
# 2431  meg issue hazardous weather outlook (hwo) http...  no_{col}
# 2432  #cityofcalgary activated municipal emergency p...  no_{col}
#
#       predicted_label  actual_label
# 0                 0.0             0
# 1                 0.0             0
# 2                 0.0             0
# 3                 0.0             0
# 4                 0.0             0
# ...               ...           ...
# 2428              0.0             0
# 2429              0.0             0
# 2430              0.0             0
# 2431              0.0             0
# 2432              0.0             0
#
# [2433 rows x 4 columns]

# %%
accuracy = len(right_predictions)*100/len(predicted_data)
accuracy
# Out:
# 74.56328532025744

# %%
import psycopg2
from psycopg2 import OperationalError

try:
    conn = psycopg2.connect(
        dbname="machineLearning",
        user="postgres",
        password="P@$$w0rd",
        host="localhost",
        port="5432"
    )

    cur = conn.cursor()
    print("Connection successful!")

except OperationalError as e:
    print(f"Error: Unable to connect to the database\n{e}")

finally:
    try:
        cur.close()
        conn.close()
    except NameError:
        pass
# Out:
# Error: Unable to connect to the database
# connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
import psycopg2

db_params = {
    "dbname": "machineLearning",
    "user": "postgres",
    "password": "P@$$w0rd",
    "host": "localhost",
    "port": "5432",
}

try:
    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    cur.execute('''
        CREATE TABLE IF NOT EXISTS predicted_tweets (
            id SERIAL PRIMARY KEY,
            tweet TEXT,
            location TEXT
        )
    ''')
    
    for i in range(len(right_predictions)):
        cur.execute('''
            INSERT INTO predicted_tweets (tweet, location) VALUES (%s, %s)
        ''', (right_predictions['tweet'][i], right_predictions['location'][i]))
    
    conn.commit()
    print("Data inserted successfully!")

except psycopg2.Error as e:
    print(f"An error occurred: {e}")

finally:
    if conn:
        conn.close()
# Out:
# An error occurred: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[299], line 35
#      32     print(f"An error occurred: {e}")
#      34 finally:
# ---> 35     if conn:
#      36         conn.close()
#
# NameError: name 'conn' is not defined
